# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from gurobipy import *
import pickle
from itertools import chain, combinations

# %%
uti = pd.read_csv("utilities.csv", sep=";")["[0.67, 0.33]"]

# %%
uti = [float(u.replace(",", ".")) for u in list(uti)]

# %%
uti
# Out:
# [0.694725,
#  0.665,
#  0.862225,
#  0.8069500000000001,
#  0.5255500000000001,
#  0.75,
#  0.887775,
#  0.944725,
#  0.8894500000000001,
#  0.75,
#  0.6097250000000001,
#  0.8052750000000001,
#  0.720275,
#  0.637775,
#  0.8894500000000001,
#  0.5825,
#  0.665,
#  0.5825,
#  0.75,
#  0.6675000000000001]

# %%
may_portfolio = pd.read_csv("67_33_50_may.csv", sep=";")

# %%
june_porfolio = pd.read_csv("67_33_50.csv", sep=";")

# %% [markdown]
# ## Processing June

# %%
df2 = pd.read_excel("inter_updated.xlsx", header=None)

score_list = []
for i in range(20):
    print("i: ", i)
    for j in range(i, 19):
        print("j: ",j)
        score = df2.iloc[i,j]
        if type(score) == str:
            score_list.append(score.replace(' ', ''))
            
score_dict = {'+':0.33, '++': 0.66, '+++': 1, '+++(+)': (1+1.33)/2,'+/-':0, '-':-0.33, '0/+':(0.33/2) }
# Out:
# i:  0
# j:  0
# j:  1
# j:  2
# j:  3
# j:  4
# j:  5
# j:  6
# j:  7
# j:  8
# j:  9
# j:  10
# j:  11
# j:  12
# j:  13
# j:  14
# j:  15
# j:  16
# j:  17
# j:  18
# i:  1
# j:  1
# j:  2
# j:  3
# j:  4
# j:  5
# j:  6
# j:  7
# j:  8
# j:  9
# j:  10
# j:  11
# j:  12
# j:  13
# j:  14
# j:  15
# j:  16
# j:  17
# j:  18
# i:  2
# j:  2
# j:  3
# j:  4
# j:  5
# j:  6
# j:  7
# j:  8
# j:  9
# j:  10
# j:  11
# j:  12
# j:  13
# j:  14
# j:  15
# j:  16
# j:  17
# j:  18
# i:  3
# j:  3
# j:  4
# j:  5
# j:  6
# j:  7
# j:  8
# j:  9
# j:  10
# j:  11
# j:  12
# j:  13
# j:  14
# j:  15
# j:  16
# j:  17
# j:  18
# i:  4
# j:  4
# j:  5
# j:  6
# j:  7
# j:  8
# j:  9
# j:  10
# j:  11
# j:  12
# j:  13
# j:  14
# j:  15
# j:  16
# j:  17
# j:  18
# i:  5
# j:  5
# j:  6
# j:  7
# j:  8
# j:  9
# j:  10
# j:  11
# j:  12
# j:  13
# j:  14
# j:  15
# j:  16
# j:  17
# j:  18
# i:  6
# j:  6
# j:  7
# j:  8
# j:  9
# j:  10
# j:  11
# j:  12
# j:  13
# j:  14
# j:  15
# j:  16
# j:  17
# j:  18
# i:  7
# j:  7
# j:  8
# j:  9
# j:  10
# j:  11
# j:  12
# j:  13
# j:  14
# j:  15
# j:  16
# j:  17
# j:  18
# i:  8
# j:  8
# j:  9
# j:  10
# j:  11
# j:  12
# j:  13
# j:  14
# j:  15
# j:  16
# j:  17
# j:  18
# i:  9
# j:  9
# j:  10
# j:  11
# j:  12
# j:  13
# j:  14
# j:  15
# j:  16
# j:  17
# j:  18
# i:  10
# j:  10
# j:  11
# j:  12
# j:  13
# j:  14
# j:  15
# j:  16
# j:  17
# j:  18
# i:  11
# j:  11
# j:  12
# j:  13
# j:  14
# j:  15
# j:  16
# j:  17
# j:  18
# i:  12
# j:  12
# j:  13
# j:  14
# j:  15
# j:  16
# j:  17
# j:  18
# i:  13
# j:  13
# j:  14
# j:  15
# j:  16
# j:  17
# j:  18
# i:  14
# j:  14
# j:  15
# j:  16
# j:  17
# j:  18
# i:  15
# j:  15
# j:  16
# j:  17
# j:  18
# i:  16
# j:  16
# j:  17
# j:  18
# i:  17
# j:  17
# j:  18
# i:  18
# j:  18
# i:  19

# %%
score_df = pd.DataFrame()
score_df["effect"] = score_dict.keys()
score_df["gamma"] = score_dict.values()
score_df.to_csv("effect")

# %%
inter_subset = []
inter_effect = []

for i in range(20):
    for j in range(i, 19):
        score = df2.iloc[i,j]
        if type(score) == str:
            score = score.replace(' ', '')
            
            try:
                inter_effect.append(score_dict[score])
                inter_subset.append([i,j+1])
            except:
                pass

# %%
def cal_add_uti(pf):
    return sum(list((uti*pf for uti, pf in zip(uti, pf))))

def cal_inter_effect(pf, inter_subset, inter_effect):   
    
    total_effect=0
    for i in range(len(inter_subset)):
        (p1, p2) = inter_subset[i]
        if ((pf[p1] == 1) & (pf[p2] == 1)):
            total_effect += avg_u*inter_effect[i]
            #print((p1, p2))
            #print(inter_effect[i])
            
    return total_effect

# %%
pf_uti = cal_add_uti(pf)
pf_inter_effect = cal_inter_effect(pf)

# %%
pf1 = june_portfolio["0.01"]
pf2 = june_portfolio["0.02"]

a = cal_add_uti(pf1)
b = cal_inter_effect(pf1, inter_subset, inter_effect)
a2 = cal_add_uti(pf2)
b2 = cal_inter_effect(pf2, inter_subset, inter_effect)

(a2-a)/(b-b2)
# Out:
# 0.012192658858551829

# %%
betas = [float(x) for x in (june_portfolio.columns[1:])]

# %%
beta_trans = []

for pair in list(combinations(june_portfolio.columns[1:], 2)):
    pf1= june_portfolio[pair[0]]
    pf2= june_portfolio[pair[1]]

    a = cal_add_uti(pf1)
    b = cal_inter_effect(pf1, inter_subset, inter_effect)
    a2 = cal_add_uti(pf2)
    b2 = cal_inter_effect(pf2, inter_subset, inter_effect)
    
    beta_com = (a2-a)/(b-b2)
    if not np.isnan(beta_com):
        beta_trans.append(beta_com)
# Out:
# /var/folders/m0/4kgydjmn6590r2xq4gdjzq3m0000gn/T/ipykernel_49453/2728932284.py:12: RuntimeWarning: invalid value encountered in double_scalars
#   beta_com = (a2-a)/(b-b2)

# %%
set(beta_trans)
# Out:
# {0.012192658858551829,
#  0.022958556568482568,
#  0.033214734587699246,
#  0.040938682639498854,
#  0.05952423258161068,
#  0.06886354950063718,
#  0.09948150831784199,
#  0.11509308137481138,
#  0.13716886738292475,
#  0.17105321019163375,
#  0.1863009468327092,
#  0.19032979144454143,
#  0.23321196451406537,
#  0.3026306280263046,
#  0.31707654448761874,
#  0.37261003377274227,
#  0.4418977857371066,
#  0.4994467416702307,
#  0.5266326226575345,
#  0.5843972864481648,
#  0.7254110245252913}

# %%
df = pd.read_csv("data.csv", sep=";", index_col=0)

# %%
int_col =[str(i) for i in range(1,21)]

pos_subsets = []
neg_subsets = []

for i in range(1,21): #for loop for row
    for j in range(1,21): #for loop for columns
        val = df[int_col].loc[i][str(j)]
        print((i,j))
        print(val)
        if val == 1.0 or val == "1":
            print("pos")
            pos_subsets.append((i-1, j-1))
        elif val == "1, -1" or val == '1, -1 ':
            pos_subsets.append((i-1,j-1))
            neg_subsets.append((i-1,j-1))
        elif val == -1.0 or val == "-1":
            neg_subsets.append((i-1,j-1))
        else:
            pass
# Out:
# (1, 1)
# nan
# (1, 2)
# nan
# (1, 3)
# nan
# (1, 4)
# 1
# pos
# (1, 5)
# 1.0
# pos
# (1, 6)
# 1.0
# pos
# (1, 7)
# -1
# (1, 8)
# nan
# (1, 9)
# -1
# (1, 10)
# nan
# (1, 11)
# nan
# (1, 12)
# nan
# (1, 13)
# nan
# (1, 14)
# nan
# (1, 15)
# nan
# (1, 16)
# nan
# (1, 17)
# nan
# (1, 18)
# nan
# (1, 19)
# nan
# (1, 20)
# nan
# (2, 1)
# nan
# (2, 2)
# nan
# (2, 3)
# 1.0
# pos
# (2, 4)
# nan
# (2, 5)
# 1.0
# pos
# (2, 6)
# -1.0
# (2, 7)
# nan
# (2, 8)
# nan
# (2, 9)
# nan
# (2, 10)
# nan
# (2, 11)
# nan
# (2, 12)
# nan
# (2, 13)
# 1
# pos
# (2, 14)
# 1.0
# pos
# (2, 15)
# nan
# (2, 16)
# nan
# (2, 17)
# nan
# (2, 18)
# nan
# (2, 19)
# nan
# (2, 20)
# nan
# (3, 1)
# nan
# (3, 2)
# -1.0
# (3, 3)
# nan
# (3, 4)
# 1, -1
# (3, 5)
# nan
# (3, 6)
# 1.0
# pos
# (3, 7)
# nan
# (3, 8)
# nan
# (3, 9)
# nan
# (3, 10)
# nan
# (3, 11)
# nan
# (3, 12)
# nan
# (3, 13)
# nan
# (3, 14)
# nan
# (3, 15)
# 1.0
# pos
# (3, 16)
# nan
# (3, 17)
# nan
# (3, 18)
# nan
# (3, 19)
# nan
# (3, 20)
# nan
# (4, 1)
# nan
# (4, 2)
# 1.0
# pos
# (4, 3)
# nan
# (4, 4)
# nan
# (4, 5)
# 1.0
# pos
# (4, 6)
# nan
# (4, 7)
# nan
# (4, 8)
# nan
# (4, 9)
# nan
# (4, 10)
# nan
# (4, 11)
# nan
# (4, 12)
# nan
# (4, 13)
# nan
# (4, 14)
# nan
# (4, 15)
# nan
# (4, 16)
# nan
# (4, 17)
# 1, -1
# (4, 18)
# nan
# (4, 19)
# nan
# (4, 20)
# nan
# (5, 1)
# nan
# (5, 2)
# 1.0
# pos
# (5, 3)
# 1.0
# pos
# (5, 4)
# -1
# (5, 5)
# nan
# (5, 6)
# -1.0
# (5, 7)
# nan
# (5, 8)
# 1.0
# pos
# (5, 9)
# nan
# (5, 10)
# nan
# (5, 11)
# nan
# (5, 12)
# nan
# (5, 13)
# nan
# (5, 14)
# nan
# (5, 15)
# nan
# (5, 16)
# nan
# (5, 17)
# nan
# (5, 18)
# nan
# (5, 19)
# nan
# (5, 20)
# nan
# (6, 1)
# nan
# (6, 2)
# 1.0
# pos
# (6, 3)
# -1.0
# (6, 4)
# nan
# (6, 5)
# -1.0
# (6, 6)
# nan
# (6, 7)
# nan
# (6, 8)
# nan
# (6, 9)
# nan
# (6, 10)
# nan
# (6, 11)
# nan
# (6, 12)
# nan
# (6, 13)
# -1
# (6, 14)
# nan
# (6, 15)
# 1.0
# pos
# (6, 16)
# nan
# (6, 17)
# nan
# (6, 18)
# nan
# (6, 19)
# 1.0
# pos
# (6, 20)
# nan
# (7, 1)
# 1.0
# pos
# (7, 2)
# nan
# (7, 3)
# nan
# (7, 4)
# nan
# (7, 5)
# nan
# (7, 6)
# nan
# (7, 7)
# nan
# (7, 8)
# nan
# (7, 9)
# 1
# pos
# (7, 10)
# nan
# (7, 11)
# nan
# (7, 12)
# nan
# (7, 13)
# 1, -1
# (7, 14)
# nan
# (7, 15)
# nan
# (7, 16)
# nan
# (7, 17)
# nan
# (7, 18)
# -1.0
# (7, 19)
# nan
# (7, 20)
# nan
# (8, 1)
# nan
# (8, 2)
# 1.0
# pos
# (8, 3)
# nan
# (8, 4)
# nan
# (8, 5)
# 1.0
# pos
# (8, 6)
# nan
# (8, 7)
# nan
# (8, 8)
# nan
# (8, 9)
# nan
# (8, 10)
# nan
# (8, 11)
# nan
# (8, 12)
# nan
# (8, 13)
# 1
# pos
# (8, 14)
# nan
# (8, 15)
# 1.0
# pos
# (8, 16)
# nan
# (8, 17)
# nan
# (8, 18)
# -1.0
# (8, 19)
# nan
# (8, 20)
# nan
# (9, 1)
# nan
# (9, 2)
# nan
# (9, 3)
# nan
# (9, 4)
# nan
# (9, 5)
# nan
# (9, 6)
# nan
# (9, 7)
# 1, -1
# (9, 8)
# nan
# (9, 9)
# nan
# (9, 10)
# nan
# (9, 11)
# nan
# (9, 12)
# nan
# (9, 13)
# nan
# (9, 14)
# nan
# (9, 15)
# nan
# (9, 16)
# nan
# (9, 17)
# nan
# (9, 18)
# nan
# (9, 19)
# nan
# (9, 20)
# nan
# (10, 1)
# nan
# (10, 2)
# 1.0
# pos
# (10, 3)
# nan
# (10, 4)
# nan
# (10, 5)
# 1.0
# pos
# (10, 6)
# nan
# (10, 7)
# nan
# (10, 8)
# nan
# (10, 9)
# nan
# (10, 10)
# nan
# (10, 11)
# nan
# (10, 12)
# nan
# (10, 13)
# 1
# pos
# (10, 14)
# nan
# (10, 15)
# nan
# (10, 16)
# nan
# (10, 17)
# nan
# (10, 18)
# nan
# (10, 19)
# nan
# (10, 20)
# nan
# (11, 1)
# nan
# (11, 2)
# 1.0
# pos
# (11, 3)
# nan
# (11, 4)
# nan
# (11, 5)
# 1.0
# pos
# (11, 6)
# nan
# (11, 7)
# nan
# (11, 8)
# nan
# (11, 9)
# nan
# (11, 10)
# nan
# (11, 11)
# nan
# (11, 12)
# nan
# (11, 13)
# 1
# pos
# (11, 14)
# nan
# (11, 15)
# nan
# (11, 16)
# 1.0
# pos
# (11, 17)
# nan
# (11, 18)
# nan
# (11, 19)
# nan
# (11, 20)
# nan
# (12, 1)
# nan
# (12, 2)
# nan
# (12, 3)
# 1.0
# pos
# (12, 4)
# nan
# (12, 5)
# nan
# (12, 6)
# -1.0
# (12, 7)
# nan
# (12, 8)
# nan
# (12, 9)
# nan
# (12, 10)
# nan
# (12, 11)
# nan
# (12, 12)
# nan
# (12, 13)
# nan
# (12, 14)
# nan
# (12, 15)
# nan
# (12, 16)
# nan
# (12, 17)
# nan
# (12, 18)
# nan
# (12, 19)
# nan
# (12, 20)
# nan
# (13, 1)
# nan
# (13, 2)
# 1.0
# pos
# (13, 3)
# nan
# (13, 4)
# nan
# (13, 5)
# 1.0
# pos
# (13, 6)
# nan
# (13, 7)
# nan
# (13, 8)
# nan
# (13, 9)
# nan
# (13, 10)
# nan
# (13, 11)
# 1.0
# pos
# (13, 12)
# nan
# (13, 13)
# nan
# (13, 14)
# 1.0
# pos
# (13, 15)
# nan
# (13, 16)
# nan
# (13, 17)
# nan
# (13, 18)
# nan
# (13, 19)
# nan
# (13, 20)
# nan
# (14, 1)
# nan
# (14, 2)
# 1.0
# pos
# (14, 3)
# nan
# (14, 4)
# nan
# (14, 5)
# 1.0
# pos
# (14, 6)
# nan
# (14, 7)
# nan
# (14, 8)
# nan
# (14, 9)
# nan
# (14, 10)
# nan
# (14, 11)
# nan
# (14, 12)
# nan
# (14, 13)
# 1
# pos
# (14, 14)
# nan
# (14, 15)
# nan
# (14, 16)
# 1.0
# pos
# (14, 17)
# nan
# (14, 18)
# nan
# (14, 19)
# nan
# (14, 20)
# nan
# (15, 1)
# nan
# (15, 2)
# 1.0
# pos
# (15, 3)
# nan
# (15, 4)
# nan
# (15, 5)
# 1.0
# pos
# (15, 6)
# nan
# (15, 7)
# 1
# pos
# (15, 8)
# nan
# (15, 9)
# nan
# (15, 10)
# nan
# (15, 11)
# nan
# (15, 12)
# nan
# (15, 13)
# 1
# pos
# (15, 14)
# nan
# (15, 15)
# nan
# (15, 16)
# nan
# (15, 17)
# nan
# (15, 18)
# nan
# (15, 19)
# nan
# (15, 20)
# nan
# (16, 1)
# nan
# (16, 2)
# nan
# (16, 3)
# nan
# (16, 4)
# nan
# (16, 5)
# nan
# (16, 6)
# nan
# (16, 7)
# nan
# (16, 8)
# nan
# (16, 9)
# 1, -1
# (16, 10)
# nan
# (16, 11)
# nan
# (16, 12)
# nan
# (16, 13)
# 1
# pos
# (16, 14)
# nan
# (16, 15)
# nan
# (16, 16)
# nan
# (16, 17)
# nan
# (16, 18)
# -1.0
# (16, 19)
# nan
# (16, 20)
# nan
# (17, 1)
# nan
# (17, 2)
# 1.0
# pos
# (17, 3)
# nan
# (17, 4)
# 1
# pos
# (17, 5)
# nan
# (17, 6)
# nan
# (17, 7)
# nan
# (17, 8)
# nan
# (17, 9)
# nan
# (17, 10)
# nan
# (17, 11)
# nan
# (17, 12)
# nan
# (17, 13)
# nan
# (17, 14)
# nan
# (17, 15)
# nan
# (17, 16)
# nan
# (17, 17)
# nan
# (17, 18)
# nan
# (17, 19)
# nan
# (17, 20)
# nan
# (18, 1)
# nan
# (18, 2)
# nan
# (18, 3)
# nan
# (18, 4)
# nan
# (18, 5)
# nan
# (18, 6)
# nan
# (18, 7)
# 1
# pos
# (18, 8)
# nan
# (18, 9)
# nan
# (18, 10)
# nan
# (18, 11)
# nan
# (18, 12)
# nan
# (18, 13)
# 1
# pos
# (18, 14)
# nan
# (18, 15)
# nan
# (18, 16)
# nan
# (18, 17)
# nan
# (18, 18)
# nan
# (18, 19)
# nan
# (18, 20)
# nan
# (19, 1)
# nan
# (19, 2)
# nan
# (19, 3)
# nan
# (19, 4)
# nan
# (19, 5)
# nan
# (19, 6)
# nan
# (19, 7)
# nan
# (19, 8)
# nan
# (19, 9)
# nan
# (19, 10)
# nan
# (19, 11)
# nan
# (19, 12)
# nan
# (19, 13)
# nan
# (19, 14)
# nan
# (19, 15)
# nan
# (19, 16)
# nan
# (19, 17)
# nan
# (19, 18)
# nan
# (19, 19)
# nan
# (19, 20)
# nan
# (20, 1)
# nan
# (20, 2)
# nan
# (20, 3)
# nan
# (20, 4)
# nan
# (20, 5)
# nan
# (20, 6)
# nan
# (20, 7)
# nan
# (20, 8)
# nan
# (20, 9)
# nan
# (20, 10)
# nan
# (20, 11)
# nan
# (20, 12)
# nan
# (20, 13)
# nan
# (20, 14)
# nan
# (20, 15)
# nan
# (20, 16)
# nan
# (20, 17)
# nan
# (20, 18)
# nan
# (20, 19)
# nan
# (20, 20)
# nan

# %%
class Project:
    def __init__(self, num=0, desc=0, a1=0, a2=0, w=[1/2, 1/2], cost=1):
        self.num = num
        self.desc = desc
        self.a1 = a1
        self.a2 = a2    
        self.cost = cost
        self.w = w
                
    def cal_value(self):
        self.value = (self.a1/4)*self.w[0] + (self.a2/4)*self.w[1]
        
    def describe(self):
        print("Project " + self.desc)
        print("a1: ", self.a1)
        print("a2: ", self.a2)
        print("cost: ", self.cost)
        print("w: ", self.w)
        print("value: ", self.value)

project_list = []
for i in range(20):
    r = df.iloc[i]
    
    p = Project(num=i+1)
    p.desc = r["Action idea name"]
    p.a1 = float(r["Hiilineutraalisuus carbon neutrality (avg)  "].replace(',', '.'))
    p.a2 = float(r["Varautuminen Resilience (avg)  "].replace(',', '.'))
    p.pos_impact = float(r["Positiiviset vaikutukset (avg)  "].replace(',', '.'))
    p.neg_impact = float(r["Negatiiviset vaikutukset (neg. impact)  (avg)  "].replace(',', '.'))
    p.cal_value()
    
    project_list.append(p)

# %%
effect_dict = {}
for subset in pos_subsets:
    ss_key = tuple(sorted(subset))
    if ss_key in effect_dict:
        effect_dict[ss_key].append(project_list[subset[0]].pos_impact)
    else:
        effect_dict[ss_key] = [project_list[subset[0]].pos_impact]
    
for subset in neg_subsets:
    ss_key = tuple(sorted(subset))
    if ss_key in effect_dict:
        effect_dict[ss_key].append(project_list[subset[0]].neg_impact)
    else:
        effect_dict[ss_key] = [project_list[subset[0]].neg_impact]

# %%
effect_dict
# Out:
# {(0, 3): [3.67],
#  (0, 4): [3.67],
#  (0, 5): [3.67],
#  (1, 2): [3.5, -1.5],
#  (1, 4): [3.5, 3.0],
#  (1, 12): [3.5, 2.67],
#  (1, 13): [3.5, 3.33],
#  (2, 3): [3.5, -1.5],
#  (2, 5): [3.5, -2.33],
#  (2, 14): [3.5],
#  (1, 3): [3.5],
#  (3, 4): [3.5, -0.5],
#  (3, 16): [3.5, 3.5, -1.0],
#  (2, 4): [3.0],
#  (4, 7): [3.0, 4.0],
#  (1, 5): [2.33, -0.5],
#  (5, 14): [2.33],
#  (5, 18): [2.33],
#  (0, 6): [4.0, -0.5],
#  (6, 8): [4.0, 4.0, -1.0],
#  (6, 12): [4.0, 0.0],
#  (1, 7): [4.0],
#  (7, 12): [4.0],
#  (7, 14): [4.0],
#  (1, 9): [3.67],
#  (4, 9): [3.67],
#  (9, 12): [3.67],
#  (1, 10): [2.67],
#  (4, 10): [2.67],
#  (10, 12): [2.67, 2.67],
#  (10, 15): [2.67],
#  (2, 11): [3.0],
#  (4, 12): [2.67],
#  (12, 13): [2.67, 3.33],
#  (4, 13): [3.33],
#  (13, 15): [3.33],
#  (1, 14): [3.0],
#  (4, 14): [3.0],
#  (6, 14): [3.0],
#  (12, 14): [3.0],
#  (8, 15): [3.5, -2.0],
#  (12, 15): [3.5],
#  (1, 16): [3.5],
#  (6, 17): [2.5, 0.0],
#  (12, 17): [2.5],
#  (0, 8): [-0.5],
#  (4, 5): [-0.5, -2.33],
#  (5, 12): [-2.33],
#  (7, 17): [-0.33],
#  (5, 11): [-0.33],
#  (15, 17): [-2.0]}

# %%
uti
# Out:
# [0.694725,
#  0.665,
#  0.862225,
#  0.8069500000000001,
#  0.5255500000000001,
#  0.75,
#  0.887775,
#  0.944725,
#  0.8894500000000001,
#  0.75,
#  0.6097250000000001,
#  0.8052750000000001,
#  0.720275,
#  0.637775,
#  0.8894500000000001,
#  0.5825,
#  0.665,
#  0.5825,
#  0.75,
#  0.6675000000000001]

# %%
inter_effect_may
# Out:
# [0.5143581508031251,
#  0.334990924040625,
#  0.478057640625,
#  0.14334490625000001,
#  0.28396123437500004,
#  0.36941554234375007,
#  0.36209277015624997,
#  0.1739431159375,
#  0.0945753046875,
#  0.67104277296875,
#  0.46954403125000005,
#  0.15903471468750002,
#  0.26831087500000006,
#  0.33985676156250005,
#  0.4344376957812501,
#  0.11408906250000002,
#  0.38857846875,
#  0.32765625,
#  0.2698322755078125,
#  0.46061835968750003,
#  0.3197210690625,
#  0.6282421250000001,
#  0.6804617993750001,
#  0.8402856512500001,
#  0.457603125,
#  0.36164409375000006,
#  0.495639234375,
#  0.27064930593750003,
#  0.21389434997812504,
#  0.29314575764531253,
#  0.23707251234375004,
#  0.5207461776562501,
#  0.252675801271875,
#  0.34453004109374996,
#  0.27903955716562506,
#  0.30927702796875,
#  0.44361318750000006,
#  0.3505878356250001,
#  0.5922236053125001,
#  0.48048644906250004,
#  0.0971446171875,
#  0.3671151640625,
#  0.386946875,
#  0.16160279296875,
#  0.2622251171875,
#  -0.07724039390625001,
#  -0.13943498437500002,
#  -0.314670140625,
#  -0.04539994078125001,
#  -0.049826390625,
#  -0.16965312500000002]

# %%
inter_effect_may = []

for k, val in effect_dict.items():
    #print(k)
    #print(val)
    effect = 0.25*np.mean(val)*uti[k[0]]*uti[k[1]]
    inter_effect_may.append(effect)

# %%
inter_subset_may = list(effect_dict.keys() )

# %%
beta_trans_may = []

for pair in list(combinations(may_portfolio.columns[1:], 2)):
    pf1= may_portfolio[pair[0]]
    pf2= may_portfolio[pair[1]]

    a = cal_add_uti(pf1)
    b = cal_inter_effect(pf1, inter_subset_may, inter_effect_may)
    a2 = cal_add_uti(pf2)
    b2 = cal_inter_effect(pf2, inter_subset_may, inter_effect_may)
    
    beta_com = (a2-a)/(b-b2)
    if not np.isnan(beta_com):
        beta_trans_may.append(beta_com)
# Out:
# /var/folders/m0/4kgydjmn6590r2xq4gdjzq3m0000gn/T/ipykernel_49453/2470031469.py:12: RuntimeWarning: invalid value encountered in double_scalars
#   beta_com = (a2-a)/(b-b2)

# %%
set(beta_trans_may)
# Out:
# {0.030344954067797164,
#  0.041918244030215136,
#  0.048369510481635535,
#  0.09968630737425399,
#  0.122500171841109,
#  0.13268187586864988,
#  0.1616468947966946,
#  0.2292757577369786,
#  0.27849301738918175,
#  0.40266050576085993}
